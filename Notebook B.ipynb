# %%
#Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random as rand

# %%
#Upload data
data = pd.read_csv("audi_used_cars.csv")

# %%
#Randomly select two columns
cols = list(data.columns)
var1 = rand.choice(cols)
var2 = rand.choice(cols)

#Check that the variables selected are not the same
while var2 == var1:
    var2 = rand.choice(cols)

data[[var1,var2]].head()
# Out:
#    tax  engineSize
# 0  150         1.4
# 1   20         2.0
# 2   30         1.4
# 3  145         2.0
# 4  145         1.0

# %%
plt.scatter(data[var1],data[var2])

# %%
print(var2)
# Out:
# engineSize

# %%
print(np.average(data[var2]))
# Out:
# 1.9307086614173228

# %%
data[var]
# Out:
# array([0. , 1. , 1.2, 1.4, 1.5, 1.6, 1.8, 1.9, 2. , 2.5, 2.7, 2.9, 3. ,
#        3.2, 4. , 4.1, 4.2, 5.2, 6.3])

# %%
np.median(data[var1])
# Out:
# 145.0
