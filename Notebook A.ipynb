# %%
#Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random as rand

# %%
#Upload data
data = pd.read_csv("audi_used_cars.csv")

# %%
#Randomly select two columns
cols = list(data.columns)
var1 = rand.choice(cols)
var2 = rand.choice(cols)

#Check that the variables selected are not the same
while var2 == var1:
    var2 = rand.choice(cols)

data[[var1,var2]].head()
# Out:
#    engineSize   mpg
# 0         1.4  55.4
# 1         2.0  64.2
# 2         1.4  55.4
# 3         2.0  67.3
# 4         1.0  49.6

# %%
plt.scatter(data[var1],data[var2])

# %%
print(var1)
# Out:
# engineSize

# %%
print(np.average(data[var1]))
# Out:
# 1.9307086614173228

# %%
np.array(data[var1])
# Out:
# array([1.4, 2. , 1.4, ..., 1. , 1.4, 1.4])

# %%
sum(data[var1])
# Out:
# 20596.79999999996
